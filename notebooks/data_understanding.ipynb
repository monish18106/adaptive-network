# %%
import pandas as pd
file1 = pd.read_csv('D:\\adaptive network\\data\\raw\\Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')
file2 = pd.read_csv('D:\\adaptive network\\data\\raw\\Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
file3 = pd.read_csv('D:\\adaptive network\\data\\raw\\Friday-WorkingHours-Morning.pcap_ISCX.csv')
file4 = pd.read_csv('D:\\adaptive network\\data\\raw\\Monday-WorkingHours.pcap_ISCX.csv')
file5 = pd.read_csv('D:\\adaptive network\\data\\raw\\Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')
file6 = pd.read_csv('D:\\adaptive network\\data\\raw\\Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')
file7 = pd.read_csv('D:\\adaptive network\\data\\raw\\Tuesday-WorkingHours.pcap_ISCX.csv')
file8 = pd.read_csv('D:\\adaptive network\\data\\raw\\Wednesday-workingHours.pcap_ISCX.csv')

a1 = list(file1.columns)
a2 = list(file2.columns)
a3 = list(file3.columns)
a4 = list(file4.columns)
a5 = list(file5.columns)
a6 = list(file6.columns)
a7 = list(file7.columns)
a8 = list(file8.columns)

# %%
a =  [a1,a2, a3, a4, a5, a6, a7, a8]
f = [file1,file2, file3, file4, file5, file6, file7, file8]
for i in f:
    print(i.shape)
# Out:
# (225745, 79)
# (286467, 79)
# (191033, 79)
# (529918, 79)
# (288602, 79)
# (170366, 79)
# (445909, 79)
# (692703, 79)

# %%
for i in f[1:]:
    if file1.dtypes.equals(i.dtypes):
        print("True")
    else:
        print("False")
# Out:
# True
# True
# True
# True
# True
# True
# True

# %%
for i in f:
    print(i.isnull().sum())
# Out:
#  Destination Port              0
#  Flow Duration                 0
#  Total Fwd Packets             0
#  Total Backward Packets        0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      0
#  Idle Std                      0
#  Idle Max                      0
#  Idle Min                      0
#  Label                         0
# Length: 79, dtype: int64
#  Destination Port              0
#  Flow Duration                 0
#  Total Fwd Packets             0
#  Total Backward Packets        0
# Total Length of Fwd Packets    0
#                               ..
# Idle Mean                      0
#  Idle Std                      0
#  Idle Max                      0
#  Idle Min                      0
#  Label                         0
# Length: 79, dtype: int64
#  Destination Port              0
#  Flow Duration                 0
#  Total Fwd Packets             0
#  Total Backward Packets        0
# Total Length of Fwd Packets    0
# ...

# %%
import numpy as np

# %%
pd.set_option('display.max_rows', None)
for i in f:
    print(np.isinf(i.select_dtypes(include='number')).sum())
# Out:
#  Destination Port                0
#  Flow Duration                   0
#  Total Fwd Packets               0
#  Total Backward Packets          0
# Total Length of Fwd Packets      0
#  Total Length of Bwd Packets     0
#  Fwd Packet Length Max           0
#  Fwd Packet Length Min           0
#  Fwd Packet Length Mean          0
#  Fwd Packet Length Std           0
# Bwd Packet Length Max            0
#  Bwd Packet Length Min           0
#  Bwd Packet Length Mean          0
#  Bwd Packet Length Std           0
# Flow Bytes/s                    30
#  Flow Packets/s                 34
#  Flow IAT Mean                   0
#  Flow IAT Std                    0
#  Flow IAT Max                    0
#  Flow IAT Min                    0
# Fwd IAT Total                    0
#  Fwd IAT Mean                    0
#  Fwd IAT Std                     0
#  Fwd IAT Max                     0
#  Fwd IAT Min                     0
# Bwd IAT Total                    0
#  Bwd IAT Mean                    0
# ...

# %%
for i in f:
    i.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
pd.set_option('display.max_rows', None)
for i in f:
    print(np.isinf(i.select_dtypes(include='number')).sum())
# Out:
#  Destination Port               0
#  Flow Duration                  0
#  Total Fwd Packets              0
#  Total Backward Packets         0
# Total Length of Fwd Packets     0
#  Total Length of Bwd Packets    0
#  Fwd Packet Length Max          0
#  Fwd Packet Length Min          0
#  Fwd Packet Length Mean         0
#  Fwd Packet Length Std          0
# Bwd Packet Length Max           0
#  Bwd Packet Length Min          0
#  Bwd Packet Length Mean         0
#  Bwd Packet Length Std          0
# Flow Bytes/s                    0
#  Flow Packets/s                 0
#  Flow IAT Mean                  0
#  Flow IAT Std                   0
#  Flow IAT Max                   0
#  Flow IAT Min                   0
# Fwd IAT Total                   0
#  Fwd IAT Mean                   0
#  Fwd IAT Std                    0
#  Fwd IAT Max                    0
#  Fwd IAT Min                    0
# Bwd IAT Total                   0
#  Bwd IAT Mean                   0
# ...

# %%
for i in f:
    print(i.duplicated().sum())
# Out:
# 2633
# 72353
# 6888
# 26935
# 35630
# 6066
# 24065
# 81909

# %%
for i in f:
    print(i.duplicated().sum())
    i = i.drop_duplicates(inplace=True)
# Out:
# 2633
# 72353
# 6888
# 26935
# 35630
# 6066
# 24065
# 81909

# %%
for i in f:
    print(i.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
for i in f:
    print(i.isnull().sum())
    i = i.dropna(inplace=True)
# Out:
#  Destination Port                0
#  Flow Duration                   0
#  Total Fwd Packets               0
#  Total Backward Packets          0
# Total Length of Fwd Packets      0
#  Total Length of Bwd Packets     0
#  Fwd Packet Length Max           0
#  Fwd Packet Length Min           0
#  Fwd Packet Length Mean          0
#  Fwd Packet Length Std           0
# Bwd Packet Length Max            0
#  Bwd Packet Length Min           0
#  Bwd Packet Length Mean          0
#  Bwd Packet Length Std           0
# Flow Bytes/s                    30
#  Flow Packets/s                 30
#  Flow IAT Mean                   0
#  Flow IAT Std                    0
#  Flow IAT Max                    0
#  Flow IAT Min                    0
# Fwd IAT Total                    0
#  Fwd IAT Mean                    0
#  Fwd IAT Std                     0
#  Fwd IAT Max                     0
#  Fwd IAT Min                     0
# Bwd IAT Total                    0
#  Bwd IAT Mean                    0
# ...

# %%
for i in f:
    print(i.isnull().sum())
# Out:
#  Destination Port               0
#  Flow Duration                  0
#  Total Fwd Packets              0
#  Total Backward Packets         0
# Total Length of Fwd Packets     0
#  Total Length of Bwd Packets    0
#  Fwd Packet Length Max          0
#  Fwd Packet Length Min          0
#  Fwd Packet Length Mean         0
#  Fwd Packet Length Std          0
# Bwd Packet Length Max           0
#  Bwd Packet Length Min          0
#  Bwd Packet Length Mean         0
#  Bwd Packet Length Std          0
# Flow Bytes/s                    0
#  Flow Packets/s                 0
#  Flow IAT Mean                  0
#  Flow IAT Std                   0
#  Flow IAT Max                   0
#  Flow IAT Min                   0
# Fwd IAT Total                   0
#  Fwd IAT Mean                   0
#  Fwd IAT Std                    0
#  Fwd IAT Max                    0
#  Fwd IAT Min                    0
# Bwd IAT Total                   0
#  Bwd IAT Mean                   0
# ...

# %%
for i in f:
    i.columns = i.columns.str.strip()

# %%
file1.columns
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
# ...

# %%
for i in f:
    print(i["Label"].value_counts())
# Out:
# Label
# DDoS      128014
# BENIGN     95068
# Name: count, dtype: int64
# Label
# BENIGN      123083
# PortScan     90694
# Name: count, dtype: int64
# Label
# BENIGN    182096
# Bot         1948
# Name: count, dtype: int64
# Label
# BENIGN    502650
# Name: count, dtype: int64
# Label
# BENIGN          252754
# Infiltration        36
# Name: count, dtype: int64
# Label
# BENIGN                        162036
# Web Attack � Brute Force        1470
# Web Attack � XSS                 652
# Web Attack � Sql Injection        21
# Name: count, dtype: int64
# Label
# BENIGN         412476
# FTP-Patator      5931
# SSH-Patator      3219
# Name: count, dtype: int64
# Label
# BENIGN              416736
# DoS Hulk            172846
# DoS GoldenEye        10286
# DoS slowloris         5385
# DoS Slowhttptest      5228
# Heartbleed              11
# Name: count, dtype: int64

# %%
for i in f:
    print(len(i),i["Label"].value_counts())
# Out:
# 223082 Label
# DDoS      128014
# BENIGN     95068
# Name: count, dtype: int64
# 213777 Label
# BENIGN      123083
# PortScan     90694
# Name: count, dtype: int64
# 184044 Label
# BENIGN    182096
# Bot         1948
# Name: count, dtype: int64
# 502650 Label
# BENIGN    502650
# Name: count, dtype: int64
# 252790 Label
# BENIGN          252754
# Infiltration        36
# Name: count, dtype: int64
# 164179 Label
# BENIGN                        162036
# Web Attack � Brute Force        1470
# Web Attack � XSS                 652
# Web Attack � Sql Injection        21
# Name: count, dtype: int64
# 421626 Label
# BENIGN         412476
# FTP-Patator      5931
# SSH-Patator      3219
# Name: count, dtype: int64
# 610492 Label
# BENIGN              416736
# DoS Hulk            172846
# DoS GoldenEye        10286
# DoS slowloris         5385
# DoS Slowhttptest      5228
# Heartbleed              11
# Name: count, dtype: int64

# %%
o = list(map(int, ["128014", "95068", "0", "0", "0", "0"]))
if sum(o) == 223082:
    print("True")
# Out:
# True

# %%
for i in f:
    print(i.shape)
# Out:
# (223082, 79)
# (213777, 79)
# (184044, 79)
# (502650, 79)
# (252790, 79)
# (164179, 79)
# (421626, 79)
# (610492, 79)

# %%
file1.columns
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
# ...

# %%
merged_df = pd.concat(f, ignore_index=True)

# %%
print(merged_df.duplicated().sum())
# Out:
# 51842

# %%
merged_df.drop_duplicates(inplace=True)
print(merged_df.duplicated().sum())
# Out:
# 0

# %%
merged_df.to_csv("CICIDS2017_Cleaned.csv", index=False)
